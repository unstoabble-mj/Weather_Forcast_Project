# %% [markdown]
# <a href="https://colab.research.google.com/github/unstoabble-mj/Weather_Forcast_Project/blob/main/Weather_Forcast_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-13035c72-6c96-4612-9893-7d4c22302e3a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-13035c72-6c96-4612-9893-7d4c22302e3a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data=pd.read_csv('file.csv')

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
 import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # ** Temperature Over Time**

# %%
data['Date/Time'] = pd.to_datetime(data['Date/Time'])
plt.figure(figsize=(12, 6))
plt.plot(data['Date/Time'], data['Temp_C'], color='tomato')
plt.title('Temperature Over Time')
plt.xlabel('Date/Time')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Humidity vs. Temperature**

# %%
 plt.figure(figsize=(8, 5))
sns.scatterplot(data=data, x='Temp_C', y='Rel Hum_%', hue='Weather', alpha=0.7)
plt.title('Humidity vs Temperature Colored by Weather Type')
plt.xlabel('Temperature (°C)')
plt.ylabel('Relative Humidity (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-15-bd03592f7530>:7: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# # **Wind Speed Distribution**

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data['Wind Speed_km/h'], bins=20, kde=True, color='skyblue')
plt.title('Wind Speed Distribution')
plt.xlabel('Wind Speed (km/h)')
plt.show()

# %% [markdown]
# # **Weather Type Count**

# %%
top_weather = data['Weather'].value_counts().nlargest(15)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_weather.values, y=top_weather.index, palette="viridis")
plt.title('Top 15 Most Frequent Weather Conditions')
plt.xlabel('Count')
plt.ylabel('Weather')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-46ef8fed9377>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_weather.values, y=top_weather.index, palette="viridis")

# %% [markdown]
# # ** Heatmap of Correlation Between Numeric Features**

# %%
plt.figure(figsize=(10, 8))
numeric_cols = ['Temp_C', 'Dew Point Temp_C', 'Rel Hum_%', 'Wind Speed_km/h', 'Visibility_km', 'Press_kPa']
sns.heatmap(data[numeric_cols].corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
